# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
city_data = "raw_data/city_data.csv"
ride_data = "raw_data/ride_data.csv"

citydata_df = pd.read_csv(city_data)
ridedata_df = pd.read_csv(ride_data)

# %%
#group by first then merger by sum
ridedata_df.head()
ridedata_d
# Out:
#           city                 date   fare        ride_id
# 0     Sarabury  2016-01-16 13:49:27  38.35  5403689035038
# 1    South Roy  2016-01-02 18:42:34  17.49  4036272335942
# 2  Wiseborough  2016-01-21 17:35:29  44.18  3645042422587
# 3  Spencertown  2016-07-31 14:53:22   6.87  2242596575892
# 4   Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673

# %%
ridedata_df_official = ridedata_data

# %%
citydata_df.head()
# Out:
#              city  driver_count   type
# 0      Kelseyland            63  Urban
# 1      Nguyenbury             8  Urban
# 2    East Douglas            12  Urban
# 3   West Dawnfurt            34  Urban
# 4  Rodriguezburgh            52  Urban

# %%
#merge the dataset on city 
mergeddata_df = pd.merge(ridedata_df,citydata_df, how = 'outer', on='city')

# %%
mergeddata_df.loc[mergeddata_df['city']=='Spencertown']
# Out:
#            city                 date   fare        ride_id  driver_count  \
# 68  Spencertown  2016-07-31 14:53:22   6.87  2242596575892            68
# 69  Spencertown  2016-07-12 02:52:31  31.39   754749022068            68
# 70  Spencertown  2016-06-13 03:01:05  25.91  7414420703015            68
# 71  Spencertown  2016-01-16 18:28:03  35.59  7002933670322            68
# 72  Spencertown  2016-08-11 12:33:41  12.76   452574991633            68
# 73  Spencertown  2016-06-14 16:52:30   8.58  8124141597846            68
# 74  Spencertown  2016-10-01 19:56:45  11.43  6593096228570            68
# 75  Spencertown  2016-05-10 04:55:12   5.13  3220127429066            68
# 76  Spencertown  2016-05-24 21:33:23  31.76  8578989365776            68
# 77  Spencertown  2016-02-12 21:25:07  30.82  8226614157011            68
# 78  Spencertown  2016-02-07 12:18:49  44.67  6135648364857            68
# 79  Spencertown  2016-03-28 06:14:53  42.67  1235393133175            68
# 80  Spencertown  2016-07-23 00:02:35   7.74  8390473678960            68
# 81  Spencertown  2016-03-04 07:28:42  44.15  2928794971925            68
# 82  Spencertown  2016-01-05 03:19:07  34.86  6293710331593            68
# 83  Spencertown  2016-02-02 16:49:37   5.85  3835492237132            68
# 84  Spencertown  2016-06-24 02:33:35  27.18  5097000600311            68
# 85  Spencertown  2016-02-16 02:44:41  21.21  5915074013717            68
# 86  Spencertown  2016-06-07 06:22:35  36.33  8193208226845            68
# 87  Spencertown  2016-10-06 08:07:19  38.31  2975852913465            68
# 88  Spencertown  2016-01-28 01:07:32  30.20  4594107221100            68
# 89  Spencertown  2016-05-17 16:18:48  34.05  4420491857291            68
# 90  Spencertown  2016-03-26 07:05:57  24.14   866422129879            68
# 91  Spencertown  2016-08-25 14:12:28  11.93  7467069564011            68
# 92  Spencertown  2016-07-19 19:03:15   7.39  2426400472885            68
# 93  Spencertown  2016-11-22 10:05:47   4.79  2729162668443            68
#
#      type
# 68  Urban
# 69  Urban
# 70  Urban
# 71  Urban
# 72  Urban
# 73  Urban
# 74  Urban
# 75  Urban
# 76  Urban
# 77  Urban
# 78  Urban
# 79  Urban
# 80  Urban
# 81  Urban
# 82  Urban
# 83  Urban
# 84  Urban
# 85  Urban
# 86  Urban
# 87  Urban
# 88  Urban
# 89  Urban
# 90  Urban
# 91  Urban
# 92  Urban
# 93  Urban

# %%
#bubble plot
#Average Fare ($) Per City
#Total Number of Rides Per City
#Total Number of Drivers Per City
#City Type (Urban, Suburban, Rural)"

bubble_plot_df = mergeddata_df[['city','fare','driver_count', 'type']]

# %%
average_ride = round(bubble_plot_df.groupby('city')['fare'].mean(),2)
total_number_rides = bubble_plot_df.groupby('city')['city'].count()
total_number_drivers = bubble_plot_df.groupby('city')['driver_count'].count()

# %%
total_number_drivers
# Out:
# city
# Alvarezhaven            31
# Alyssaberg              26
# Anitamouth               9
# Antoniomouth            22
# Aprilchester            19
# Arnoldview              31
# Campbellport            15
# Carrollbury             10
# Carrollfort             29
# Clarkstad               12
# Conwaymouth             11
# Davidtown               21
# Davistown               25
# East Cherylfurt         13
# East Douglas            22
# East Erin               28
# East Jenniferchester    19
# East Leslie             11
# East Stephen            10
# East Troybury            7
# Edwardsbury             27
# Erikport                 8
# Eriktown                19
# Floresberg              10
# Fosterside              24
# Hernandezshire           9
# Horneland                4
# Jacksonfort              6
# Jacobfort               31
# Jasonfort               12
#                         ..
# South Roy               22
# South Shannonborough    15
# Spencertown             26
# Stevensport              5
# Stewartview             30
# Swansonbury             34
# Thomastown              24
# Tiffanyton              13
# Torresshire             26
# Travisville             23
# Vickimouth              15
# Webstertown             16
# West Alexis             20
# West Brandy             30
# West Brittanyton        24
# West Dawnfurt           29
# West Evan               12
# West Jefferyfurt        21
# West Kevintown           7
# West Oscar              29
# West Pamelaborough      14
# West Paulport           17
# West Peter              31
# West Sydneyhaven        18
# West Tony               19
# Williamchester          11
# Williamshire            31
# Wiseborough             19
# Yolandafurt             20
# Zimmermanmouth          24
# Name: driver_count, Length: 125, dtype: int64

# %%
city_type = bubble_plot_df.groupby('type').nunique()

# %%
city_type = city_type[['city']]
city_type
# Out:
#           city
# type
# Rural       18
# Suburban    41
# Urban       66

# %%
#percentage of total fares by city types
total_fare = bu

# %%
#%  of total rides
type_group = bubble_plot_df.groupby('type')
count_groupbyrides = type_group['type'].count()
count_groupbyrides
colors = ['orange','lightblue','red']
explode = (0,0,.5)
piechart_percentage_totalrides = count_groupbyrides.plot(kind = 'pie', colors=colors, figsize=(9,9), autopct='%1.1f%%',
                                                         explode =explode, fontsize= 14)

piechart_percentage_totalrides.set_title("% of Total Rides by City Types", fontsize = 20)
plt.show()

# %%
# Out:
# Index(['Rural', 'Suburban', 'Urban'], dtype='object', name='type')
